# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
elderCare_data = pd.read_csv("elderly care.csv", index_col = "Year")

# %%
sns.lineplot(data = elderCare_data)
# Out:
# <Axes: xlabel='Year'>

# %%
plt.figure(figsize = (10 ,6))
plt.title("Elderly care Facility and Bed Availability")
sns.lineplot(data = elderCare_data)
# Out:
# <Axes: title={'center': 'Elderly care Facility and Bed Availability'}, xlabel='Year'>

# %%
list(elderCare_data.columns)
plt.figure(figsize = (10 ,6))
plt.title("Elderly care Facility and Bed Availability")
sns.lineplot(data = elderCare_data["Number of available beds"])
sns.lineplot(data = elderCare_data["Total occupants"])
# Out:
# <Axes: title={'center': 'Elderly care Facility and Bed Availability'}, xlabel='Year', ylabel='Number of available beds'>
